# %%
import numpy as np
import scipy as sp
import skimage
# %pylab inline

from RecipeWatchRelated import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sd = StorageDelegate()
video = sd.get_random_video()
frame = video.get_random_frame()

# %%
plt.imshow(frame.data['image'])
